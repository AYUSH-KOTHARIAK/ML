# %%
import cv2
import matplotlib.pylab as plt

# %%
vid=cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()    ## ---  shows that our camera is active
# Out:
# True

# %%
k=vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[210, 227, 210],
#          [207, 229, 210],
#          [204, 231, 210],
#          ...,
#          [118, 147, 144],
#          [115, 145, 142],
#          [113, 144, 141]],
#
#         [[210, 220, 206],
#          [204, 226, 207],
#          [197, 230, 206],
#          ...,
#          [111, 147, 136],
#          [123, 142, 136],
#          [123, 141, 135]],
#
#         [[198, 227, 197],
#          [197, 228, 197],
#          [197, 229, 199],
#          ...,
#          [119, 150, 145],
#          [128, 145, 143],
#          [129, 143, 142]],
#
#         ...,
#
#         [[ 31,  33,  26],
#          [ 26,  32,  26],
#          [ 21,  31,  26],
#          ...,
#          [  0,   6,   8],
#          [  0,   8,   9],
#          [  0,   9,  10]],
#
#         [[ 31,  39,  34],
#          [ 25,  33,  29],
#          [ 24,  31,  29],
#          ...,
#          [  0,   6,   8],
#          [  0,   7,   9],
#          [  0,   7,   9]],
#
#         [[ 30,  42,  39],
#          [ 24,  36,  34],
#          [ 23,  35,  34],
#          ...,
#          [  0,   7,   9],
#          [  0,   6,   8],
#          [  0,   5,   6]]], dtype=uint8))

# %%
m,n=(3,2)
m
# Out:
# 3

# %%
flag,img = vid.read() ##campturing in BGR Color

# %%
if flag:
    plt.imshow(img[:,:,::-1])   ## -- to view image in RGB

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
for i in range(100):
    flag,img = vid.read()
    if flag:
        plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag,img = vid.read()
    if flag:
        cv2.imshow('preview',img)
        cv2.waitKey(1)

# %%
ord('q') ##-- to fetch ascii value
# Out:
# 113

# %% [markdown]
# Capturing video[multiple images ]    To exit key q is used

# %%
vid = cv2.VideoCapture(0)
while True:  ## infinite capture from camera
    flag,img = vid.read()
    if flag:
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key == ord('q'):   ## key to exit the priview    ,, ord('') -- gives ASCII value of the keys or we can also replace it by its ASCII value
            break
    else:
        break  ## if not reading any input from camera
vid.release() ## to release camera access by code
cv2.destroyAllWindows() 
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# all capital -- constant ,
# camal case -- function ,
# all camal case -- class

# %% [markdown]
# IMAGE IN GRAY BLACK AND WHITE

# %%
vid = cv2.VideoCapture(0)
while True:  ## infinite capture from camera
    flag,img = vid.read()
    if flag:
        ##Processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)  
        th,img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)    ## for inverted video  ,, gray , black and white
        cv2.imshow('preview',img_bw)
        key=cv2.waitKey(1)
        if key == ord('q'):   ## key to exit the priview    ,, ord('') -- gives ASCII value of the keys or we can also replace it by its ASCII value
            break
    else:
        print('NO FRAME')
        break  ## if not reading any input from camera
cv2.destroyAllWindows() 
cv2.waitKey(1)
vid.release() ## to release camera access by code

# %% [markdown]
# VIEW A PARTICULAR PART OF IMAGE

# %%
fd=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
vid = cv2.VideoCapture(0)
while True:  ## infinite capture from camera
    flag,img = vid.read()
    if flag:
        ##Processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)  
        faces = fd.detectMultiScale(img_gray,1.1,5)
        th,img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)    ## for inverted video  ,, gray , black and white
        x,y,w,h = (250,200,100,100) 
        img_cropped = img[y:y+h,x:x+w,:]
        cv2.rectangle(img,pt1=(x,y),pt2=(x+w,y+h),color=(0,0,255),thickness=8)
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key == ord('q'):   ## key to exit the priview    ,, ord('') -- gives ASCII value of the keys or we can also replace it by its ASCII value
            break
    else:
        print('NO FRAME')
        break  ## if not reading any input from camera
cv2.destroyAllWindows() 
cv2.waitKey(1)
vid.release() ## to release camera access by code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       5 if flag:
#       6     ##Processing code
#       7     img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# ----> 8     faces = fd.detectMultiScale(img_gray,1.1,5)
#       9     th,img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)    ## for inverted video  ,, gray , black and white
#      10     x,y,w,h = (250,200,100,100)
#
# NameError: name 'fd' is not defined
