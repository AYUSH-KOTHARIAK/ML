# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('image.jpg')
cv2.imshow('Hello',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# NoneType

# %%
img

# %%
img1 = plt.imread('download.jpg')
plt.imshow(img1)
